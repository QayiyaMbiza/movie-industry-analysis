# %% [markdown]
# # Data Engineering
#
# ### Notebook 1: Creating a clean directory
#
# The purpose of this notebook is to extract the raw movie dataset, create the project directories, load the dataset into the Pandas DataFrame, and perform an initial inspection of the data. This step provides an understandinf of the dataset's structure and identifies any obvious quality issues before transformation begins.

# %%
import os

# %%
import os
# Location of the clean data folder
clean = r"C:\Users\bongo\OneDrive\Desktop\GitHub\Movie Analysis\Data\Clean"

# %%
os.makedirs(clean, exist_ok=True)

print("Clean directory created successfully")
# Out:
# Clean directory created successfully

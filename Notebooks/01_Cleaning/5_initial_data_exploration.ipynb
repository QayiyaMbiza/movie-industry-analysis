# %% [markdown]
# ## INITIAL DATA EXPLORATION
#
# The purpose of this notebook is to explore the cleaned movie dataset after feature engineering has been completed.
# This notebook evaluated the overall quality of the dataset by examining its structute, dimensions, data types, descriptive statistics, missing values, duplicate records, and overall completeness before loading the data into SQLite.

# %%
import pandas as pd

# %%
# Path to the clean dataset
clean = r"C:\Users\bongo\OneDrive\Desktop\GitHub\Movie Analysis\Data\Clean\cleaned_movies.csv"

# Loading the dataset
movies = pd.read_csv(clean)

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released  score      votes         director                   writer  \
# 0  1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1  1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# ...

# %%
movies.tail()
# Out:
#                name rating   genre  year    released  score  votes  \
# 7663   More to Life    NaN   Drama  2020  2020-10-23    3.1   18.0
# 7664    Dream Round    NaN  Comedy  2020  2020-02-07    4.7   36.0
# 7665  Saving Mbango    NaN   Drama  2020  2020-04-27    5.7   29.0
# 7666   It's Just Us    NaN   Drama  2020  2020-10-01    NaN    NaN
# 7667      Tee em el    NaN  Horror  2020  2020-08-19    5.7    7.0
#
#            director         writer              star        country   budget  \
# 7663  Joseph Ebanks  Joseph Ebanks      Shannon Bond  United States   7000.0
# 7664   Dusty Dukatz    Lisa Huston  Michael Saquella  United States      NaN
# 7665   Nkanya Nkwai   Lynno Lovert      Onyama Laura  United States  58750.0
# 7666  James Randall  James Randall     Christina Roz  United States  15000.0
# 7667   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso   South Africa      NaN
#
#       gross                    company  runtime  Profit  ROI released_month  \
# ...

# %%
print(f"Rows: {movies.shape[0]:,}")
print(f"Columns: {movies.shape[1]:,}")
# Out:
# Rows: 7,668
# Columns: 20

# %%
movies.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'Profit', 'ROI', 'released_month', 'release_quarter',
#        'decade'],
#       dtype='str')

# %%
movies.dtypes
# Out:
# name                   str
# rating                 str
# genre                  str
# year                 int64
# released               str
# score              float64
# votes              float64
# director               str
# writer                 str
# star                   str
# country                str
# budget             float64
# gross              float64
# company                str
# runtime            float64
# Profit             float64
# ROI                float64
# released_month         str
# release_quarter    float64
# decade               int64
# dtype: object

# %%
movies.describe(include="all")
# Out:
#          name rating   genre         year    released        score  \
# count    7668   7591    7668  7668.000000        7609  7665.000000
# unique   7512     12      19          NaN        2909          NaN
# top     Venom      R  Comedy          NaN  1986-02-14          NaN
# freq        3   3697    2245          NaN           9          NaN
# mean      NaN    NaN     NaN  2000.405451         NaN     6.390411
# std       NaN    NaN     NaN    11.153508         NaN     0.968842
# min       NaN    NaN     NaN  1980.000000         NaN     1.900000
# 25%       NaN    NaN     NaN  1991.000000         NaN     5.800000
# 50%       NaN    NaN     NaN  2000.000000         NaN     6.500000
# 75%       NaN    NaN     NaN  2010.000000         NaN     7.100000
# max       NaN    NaN     NaN  2020.000000         NaN     9.300000
#
#                votes     director       writer          star        country  \
# count   7.665000e+03         7668         7665          7667           7665
# ...

# %%
movies.isnull().sum()
# Out:
# name                  0
# rating               77
# genre                 0
# year                  0
# released             59
# score                 3
# votes                 3
# director              0
# writer                3
# star                  1
# country               3
# budget             2171
# gross               189
# company              17
# runtime               4
# Profit             2232
# ROI                2232
# released_month       59
# release_quarter      59
# decade                0
# dtype: int64

# %%
duplicates = movies.duplicated().sum()
print(f"Duplicate Records: {duplicates}")
# Out:
# Duplicate Records: 0

# %%
if duplicates > 0:
    movies[movies.duplicated()]
else:
    print('No duplicate records found')
# Out:
# No duplicate records found

# %% [markdown]
# ### INITIAL DATA QUALITY REPORT
#
# A summary report is produced to provide an overview of the dataset's overall quality.
# This report consolidates key quality metrics into a single table for easy interpretation.

# %%
quality_report = pd.DataFrame({
    
    'Metric': [
        'Rows',
        'Columns',
        'Missing Values',
        'Duplicate Records'
    ],

    'Value': [
        movies.shape[0],
        movies.shape[1],
        movies.isna().sum().sum(),
        duplicates
    ]
})

quality_report
# Out:
#               Metric  Value
# 0               Rows   7668
# 1            Columns     20
# 2     Missing Values   7112
# 3  Duplicate Records      0
